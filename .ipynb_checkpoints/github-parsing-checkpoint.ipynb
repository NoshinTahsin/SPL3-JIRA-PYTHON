# %%
import requests
from pprint import pprint

# github username
username = "NoshinTahsin"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/35559870?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2018-01-18T08:58:07Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/NoshinTahsin/events{/privacy}',
#  'followers': 14,
#  'followers_url': 'https://api.github.com/users/NoshinTahsin/followers',
#  'following': 52,
#  'following_url': 'https://api.github.com/users/NoshinTahsin/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/NoshinTahsin/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/NoshinTahsin',
#  'id': 35559870,
#  'location': None,
#  'login': 'NoshinTahsin',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjM1NTU5ODcw',
#  'organizations_url': 'https://api.github.com/users/NoshinTahsin/orgs',
#  'public_gists': 0,
#  'public_repos': 56,
#  'received_events_url': 'https://api.github.com/users/NoshinTahsin/received_events',
#  'repos_url': 'https://api.github.com/users/NoshinTahsin/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/NoshinTahsin/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/NoshinTahsin/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-03-26T16:49:17Z',
#  'url': 'https://api.github.com/users/NoshinTahsin'}

# %%
import base64
from github import Github
from pprint import pprint

# Github username
username = "NoshinTahsin"
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)
# Out:
# Repository(full_name="NoshinTahsin/Abinta-sYoungChangeLeaders")
# Repository(full_name="NoshinTahsin/AngularCourse")
# Repository(full_name="NoshinTahsin/Apriori-Python-Data-Mining-")
# Repository(full_name="NoshinTahsin/bangla-Sign-Language-Detection-ML")
# Repository(full_name="NoshinTahsin/BookShop_Angular")
# Repository(full_name="NoshinTahsin/bookshop_e-commerce")
# Repository(full_name="NoshinTahsin/BuilderPattern")
# Repository(full_name="NoshinTahsin/BuilderPatternFirstVersion")
# Repository(full_name="NoshinTahsin/CareerPath")
# Repository(full_name="NoshinTahsin/ChainOfResponsibilityPattern")
# Repository(full_name="NoshinTahsin/Codeforces")
# Repository(full_name="NoshinTahsin/CommandPattern")
# Repository(full_name="NoshinTahsin/CompositePattern")
# Repository(full_name="NoshinTahsin/CompositeShapeDraw")
# Repository(full_name="NoshinTahsin/data-analysis")
# Repository(full_name="NoshinTahsin/Data-Mining")
# Repository(full_name="NoshinTahsin/Decision-Tree")
# Repository(full_name="NoshinTahsin/DecoratorSorting")
# Repository(full_name="NoshinTahsin/defect-classification")
# Repository(full_name="NoshinTahsin/defect-prediction")
# Repository(full_name="NoshinTahsin/FlyWeightpattern")
# Repository(full_name="NoshinTahsin/four-connect")
# Repository(full_name="NoshinTahsin/frontend-task")
# Repository(full_name="NoshinTahsin/GeneralFixtureTestSmell_TestingTool")
# Repository(full_name="NoshinTahsin/GitTest")
# Repository(full_name="NoshinTahsin/ICE")
# Repository(full_name="NoshinTahsin/IIT-Debating-Club-Website-UI-")
# Repository(full_name="NoshinTahsin/IslandProblemUsingDesignPattern")
# Repository(full_name="NoshinTahsin/JUnitTestingMathPal")
# Repository(full_name="NoshinTahsin/KNN")
# Repository(full_name="NoshinTahsin/Mediator")
# Repository(full_name="NoshinTahsin/MementoPattern")
# Repository(full_name="NoshinTahsin/ML-Models")
# Repository(full_name="NoshinTahsin/NearestNeighbour")
# Repository(full_name="NoshinTahsin/NewRepo")
# Repository(full_name="NoshinTahsin/ObserverPattern")
# Repository(full_name="NoshinTahsin/ParallelComputing")
# Repository(full_name="NoshinTahsin/Phoenix")
# Repository(full_name="NoshinTahsin/ProxyPattern")
# Repository(full_name="NoshinTahsin/RMIT_repository")
# Repository(full_name="NoshinTahsin/Skin-Detection")
# Repository(full_name="NoshinTahsin/SoftwareMetrics8th")
# Repository(full_name="NoshinTahsin/SpamDetection")
# Repository(full_name="NoshinTahsin/SPL")
# Repository(full_name="NoshinTahsin/SPL1")
# Repository(full_name="NoshinTahsin/SPL3")
# Repository(full_name="NoshinTahsin/SPL3-JIRA-PYTHON")
# Repository(full_name="NoshinTahsin/StrategyPatternNotification")
# Repository(full_name="NoshinTahsin/temp")
# Repository(full_name="NoshinTahsin/TemplatePattern")
# Repository(full_name="NoshinTahsin/TestingTool-GeneralFixture")
# Repository(full_name="NoshinTahsin/TestingToolForGeneralFixtureSmell")
# Repository(full_name="NoshinTahsin/TestingToolGeneralFixture")
# Repository(full_name="NoshinTahsin/WebLabs")
# Repository(full_name="NoshinTahsin/wumpus")
# Repository(full_name="NoshinTahsin/WumpusWorldAIProject")

# %%
def print_repo(repo):
    # repository full name
    print("Full name:", repo.full_name)
    # repository description
    print("Description:", repo.description)
    # the date of when the repo was created
    print("Date created:", repo.created_at)
    # the date of the last git push
    print("Date of last push:", repo.pushed_at)
    # home website (if available)
    print("Home Page:", repo.homepage)
    # programming language
    print("Language:", repo.language)
    # number of forks
    print("Number of forks:", repo.forks)
    # number of stars
    print("Number of stars:", repo.stargazers_count)
    print("-"*50)
    # repository content (files & directories)
    # the date of when the repo was created
    print("Commits url:", repo._commits_url)
    
    try:
        # repo license
        print("License:", base64.b64decode(repo.get_license().content.encode()).decode())
    except:
        pass

# %%
# iterate over all public repositories
for repo in user.get_repos():
    print_repo(repo)
    print("="*100)
# Out:
# Full name: NoshinTahsin/Abinta-sYoungChangeLeaders
# Description: None
# Date created: 2019-08-01 07:42:38
# Date of last push: 2019-08-01 07:42:39
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/AngularCourse
# Description: None
# Date created: 2020-01-20 10:58:19
# Date of last push: 2020-01-23 13:28:20
# Home Page: None
# Language: TypeScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Apriori-Python-Data-Mining-
# Description: None
# Date created: 2019-10-05 14:28:23
# Date of last push: 2019-10-05 14:31:42
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/bangla-Sign-Language-Detection-ML
# Description: None
# Date created: 2019-12-04 17:28:59
# Date of last push: 2019-11-13 08:07:18
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/BookShop_Angular
# Description: None
# Date created: 2020-02-02 13:56:56
# Date of last push: 2020-02-06 13:58:09
# Home Page: None
# Language: TypeScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/bookshop_e-commerce
# Description: None
# Date created: 2020-01-02 12:44:01
# Date of last push: 2020-01-14 10:35:25
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/BuilderPattern
# Description: None
# Date created: 2019-10-05 15:08:27
# Date of last push: 2019-10-05 15:10:15
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/BuilderPatternFirstVersion
# Description: None
# Date created: 2019-10-05 15:13:17
# Date of last push: 2019-10-05 15:13:53
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/CareerPath
# Description: None
# Date created: 2020-01-29 12:00:06
# Date of last push: 2020-01-29 12:00:07
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ChainOfResponsibilityPattern
# Description: None
# Date created: 2019-10-05 15:14:15
# Date of last push: 2019-10-05 15:15:05
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Codeforces
# Description: None
# Date created: 2020-01-18 08:34:48
# Date of last push: 2020-07-24 13:40:50
# Home Page: None
# Language: C++
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/CommandPattern
# Description: None
# Date created: 2019-10-05 15:37:45
# Date of last push: 2019-10-05 15:40:58
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/CompositePattern
# Description: None
# Date created: 2019-10-05 15:43:12
# Date of last push: 2019-10-05 15:43:45
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/CompositeShapeDraw
# Description: None
# Date created: 2019-10-05 15:41:22
# Date of last push: 2019-10-05 15:42:08
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/data-analysis
# Description: None
# Date created: 2020-04-26 13:22:13
# Date of last push: 2020-04-28 13:52:05
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Data-Mining
# Description: None
# Date created: 2019-10-05 14:26:20
# Date of last push: 2019-10-05 14:26:20
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Decision-Tree
# Description: None
# Date created: 2019-10-05 14:33:39
# Date of last push: 2019-10-05 14:34:44
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/DecoratorSorting
# Description: None
# Date created: 2019-10-05 15:44:01
# Date of last push: 2019-10-05 15:44:25
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/defect-classification
# Description: None
# Date created: 2021-02-17 04:09:41
# Date of last push: 2021-02-17 04:12:45
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/defect-prediction
# Description: None
# Date created: 2021-02-16 15:39:44
# Date of last push: 2021-02-17 04:06:32
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/FlyWeightpattern
# Description: None
# Date created: 2019-10-05 15:47:32
# Date of last push: 2019-10-05 15:48:08
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/four-connect
# Description: four_connect game
# Date created: 2019-10-26 13:20:37
# Date of last push: 2019-08-25 05:55:54
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/frontend-task
# Description: None
# Date created: 2020-04-26 09:28:35
# Date of last push: 2020-06-01 09:57:40
# Home Page: None
# Language: HTML
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/GeneralFixtureTestSmell_TestingTool
# Description: None
# Date created: 2019-11-01 19:25:36
# Date of last push: 2019-11-02 21:25:16
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/GitTest
# Description: None
# Date created: 2020-02-03 06:44:04
# Date of last push: 2020-02-03 06:53:09
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ICE
# Description: None
# Date created: 2020-01-29 12:00:22
# Date of last push: 2020-01-30 13:14:18
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/IIT-Debating-Club-Website-UI-
# Description: None
# Date created: 2019-10-26 13:13:27
# Date of last push: 2019-10-26 13:16:08
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/IslandProblemUsingDesignPattern
# Description: None
# Date created: 2019-10-05 15:48:55
# Date of last push: 2019-10-05 15:57:52
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/JUnitTestingMathPal
# Description: None
# Date created: 2019-10-05 15:10:56
# Date of last push: 2019-10-05 15:12:39
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/KNN
# Description: None
# Date created: 2019-10-05 14:36:56
# Date of last push: 2019-10-05 14:39:44
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Mediator
# Description: None
# Date created: 2019-10-05 15:59:00
# Date of last push: 2019-10-05 15:59:44
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/MementoPattern
# Description: None
# Date created: 2019-10-05 16:00:06
# Date of last push: 2019-10-05 16:00:32
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ML-Models
# Description: None
# Date created: 2021-01-07 21:03:57
# Date of last push: 2021-01-09 14:30:24
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/NearestNeighbour
# Description: None
# Date created: 2019-10-05 14:43:17
# Date of last push: 2019-10-05 14:49:11
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/NewRepo
# Description: None
# Date created: 2020-02-03 06:54:31
# Date of last push: 2020-02-03 07:02:39
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ObserverPattern
# Description: None
# Date created: 2019-10-05 16:11:49
# Date of last push: 2019-10-05 16:13:18
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ParallelComputing
# Description: None
# Date created: 2019-10-05 18:16:56
# Date of last push: 2019-10-05 18:17:53
# Home Page: None
# Language: C
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Phoenix
# Description: None
# Date created: 2018-01-18 09:12:19
# Date of last push: 2019-08-18 06:52:04
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/ProxyPattern
# Description: None
# Date created: 2019-10-05 18:04:55
# Date of last push: 2019-10-05 18:04:55
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/RMIT_repository
# Description: None
# Date created: 2019-10-05 14:19:26
# Date of last push: 2019-10-26 12:58:34
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/Skin-Detection
# Description: None
# Date created: 2019-10-05 14:54:44
# Date of last push: 2019-10-05 14:59:07
# Home Page: None
# Language: Python
# Number of forks: 1
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SoftwareMetrics8th
# Description: None
# Date created: 2021-02-11 12:22:38
# Date of last push: 2021-02-13 11:58:24
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SpamDetection
# Description: None
# Date created: 2019-10-05 15:01:46
# Date of last push: 2019-10-05 15:02:34
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SPL
# Description: None
# Date created: 2018-02-01 10:28:00
# Date of last push: 2018-05-29 08:19:01
# Home Page: None
# Language: C++
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SPL1
# Description: None
# Date created: 2018-02-01 08:25:19
# Date of last push: 2018-02-01 08:31:44
# Home Page: None
# Language: C++
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SPL3
# Description: None
# Date created: 2020-03-27 18:01:54
# Date of last push: 2020-03-27 18:03:29
# Home Page: None
# Language: JavaScript
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/SPL3-JIRA-PYTHON
# Description: None
# Date created: 2020-12-15 14:03:40
# Date of last push: 2021-02-23 00:25:13
# Home Page: None
# Language: Jupyter Notebook
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/StrategyPatternNotification
# Description: None
# Date created: 2019-10-05 16:00:45
# Date of last push: 2019-10-05 16:02:12
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/temp
# Description: None
# Date created: 2018-02-01 09:58:36
# Date of last push: 2018-02-01 10:25:48
# Home Page: None
# Language: C++
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/TemplatePattern
# Description: None
# Date created: 2019-10-05 18:05:55
# Date of last push: 2019-10-05 18:06:23
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/TestingTool-GeneralFixture
# Description: None
# Date created: 2019-11-02 22:34:10
# Date of last push: 2019-11-04 11:17:11
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/TestingToolForGeneralFixtureSmell
# Description: None
# Date created: 2019-11-02 21:36:32
# Date of last push: 2019-11-02 21:43:42
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/TestingToolGeneralFixture
# Description: None
# Date created: 2019-11-02 21:26:29
# Date of last push: 2019-11-02 21:33:24
# Home Page: None
# Language: Java
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/WebLabs
# Description: None
# Date created: 2019-10-05 18:08:26
# Date of last push: 2019-10-05 18:13:58
# Home Page: None
# Language: HTML
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/wumpus
# Description: None
# Date created: 2019-09-30 08:28:25
# Date of last push: 2019-09-30 08:10:42
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================
# Full name: NoshinTahsin/WumpusWorldAIProject
# Description: AI Project
# Date created: 2019-09-20 12:13:30
# Date of last push: 2019-09-29 16:36:04
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# ====================================================================================================

# %%
dir(repo)
# Out:
# ['CHECK_AFTER_INIT_FLAG',
#  '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed',
#  '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute',
#  '_Repository__create_pull',
#  '_Repository__create_pull_1',
#  '_Repository__create_pull_2',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_allow_merge_commit',
#  '_allow_rebase_merge',
#  '_allow_squash_merge',
#  '_archive_url',
#  '_archived',
#  '_assignees_url',
#  '_blobs_url',
#  '_branches_url',
#  '_clone_url',
#  '_collaborators_url',
#  '_comments_url',
#  '_commits_url',
#  '_compare_url',
#  '_completeIfNeeded',
#  '_completeIfNotSet',
#  '_contents_url',
#  '_contributors_url',
#  '_created_at',
#  '_default_branch',
#  '_delete_branch_on_merge',
#  '_deployments_url',
#  '_description',
#  '_downloads_url',
#  '_events_url',
#  '_fork',
#  '_forks',
#  '_forks_count',
#  '_forks_url',
#  '_full_name',
#  '_git_commits_url',
#  '_git_refs_url',
#  '_git_tags_url',
#  '_git_url',
#  '_has_downloads',
#  '_has_issues',
#  '_has_pages',
#  '_has_projects',
#  '_has_wiki',
#  '_headers',
#  '_homepage',
#  '_hooks_url',
#  '_html_url',
#  '_hub',
#  '_id',
#  '_identity',
#  '_initAttributes',
#  '_issue_comment_url',
#  '_issue_events_url',
#  '_issues_url',
#  '_keys_url',
#  '_labels_url',
#  '_language',
#  '_languages_url',
#  '_legacy_convert_issue',
#  '_makeBoolAttribute',
#  '_makeClassAttribute',
#  '_makeDatetimeAttribute',
#  '_makeDictAttribute',
#  '_makeDictOfStringsToClassesAttribute',
#  '_makeFloatAttribute',
#  '_makeIntAttribute',
#  '_makeListOfClassesAttribute',
#  '_makeListOfDictsAttribute',
#  '_makeListOfIntsAttribute',
#  '_makeListOfListOfStringsAttribute',
#  '_makeListOfStringsAttribute',
#  '_makeStringAttribute',
#  '_makeTimestampAttribute',
#  '_master_branch',
#  '_merges_url',
#  '_milestones_url',
#  '_mirror_url',
#  '_name',
#  '_network_count',
#  '_notifications_url',
#  '_open_issues',
#  '_open_issues_count',
#  '_organization',
#  '_owner',
#  '_parent',
#  '_parentUrl',
#  '_permissions',
#  '_private',
#  '_pulls_url',
#  '_pushed_at',
#  '_rawData',
#  '_releases_url',
#  '_requester',
#  '_size',
#  '_source',
#  '_ssh_url',
#  '_stargazers_count',
#  '_stargazers_url',
#  '_statuses_url',
#  '_storeAndUseAttributes',
#  '_subscribers_count',
#  '_subscribers_url',
#  '_subscription_url',
#  '_svn_url',
#  '_tags_url',
#  '_teams_url',
#  '_trees_url',
#  '_updated_at',
#  '_url',
#  '_useAttributes',
#  '_watchers',
#  '_watchers_count',
#  'add_to_collaborators',
#  'allow_merge_commit',
#  'allow_rebase_merge',
#  'allow_squash_merge',
#  'archive_url',
#  'archived',
#  'assignees_url',
#  'blobs_url',
#  'branches_url',
#  'clone_url',
#  'collaborators_url',
#  'comments_url',
#  'commits_url',
#  'compare',
#  'compare_url',
#  'contents_url',
#  'contributors_url',
#  'create_check_run',
#  'create_check_suite',
#  'create_deployment',
#  'create_file',
#  'create_fork',
#  'create_git_blob',
#  'create_git_commit',
#  'create_git_ref',
#  'create_git_release',
#  'create_git_tag',
#  'create_git_tag_and_release',
#  'create_git_tree',
#  'create_hook',
#  'create_issue',
#  'create_key',
#  'create_label',
#  'create_milestone',
#  'create_project',
#  'create_pull',
#  'create_repository_dispatch',
#  'create_source_import',
#  'created_at',
#  'default_branch',
#  'delete',
#  'delete_branch_on_merge',
#  'delete_file',
#  'deployments_url',
#  'description',
#  'disable_automated_security_fixes',
#  'disable_vulnerability_alert',
#  'downloads_url',
#  'edit',
#  'enable_automated_security_fixes',
#  'enable_vulnerability_alert',
#  'etag',
#  'events_url',
#  'fork',
#  'forks',
#  'forks_count',
#  'forks_url',
#  'full_name',
#  'get__repr__',
#  'get_archive_link',
#  'get_assignees',
#  'get_branch',
#  'get_branches',
#  'get_check_run',
#  'get_check_suite',
#  'get_clones_traffic',
#  'get_collaborator_permission',
#  'get_collaborators',
#  'get_comment',
#  'get_comments',
#  'get_commit',
#  'get_commits',
#  'get_contents',
#  'get_contributors',
#  'get_deployment',
#  'get_deployments',
#  'get_dir_contents',
#  'get_download',
#  'get_downloads',
#  'get_events',
#  'get_forks',
#  'get_git_blob',
#  'get_git_commit',
#  'get_git_matching_refs',
#  'get_git_ref',
#  'get_git_refs',
#  'get_git_tag',
#  'get_git_tree',
#  'get_hook',
#  'get_hooks',
#  'get_issue',
#  'get_issues',
#  'get_issues_comments',
#  'get_issues_event',
#  'get_issues_events',
#  'get_key',
#  'get_keys',
#  'get_label',
#  'get_labels',
#  'get_languages',
#  'get_latest_release',
#  'get_license',
#  'get_milestone',
#  'get_milestones',
#  'get_network_events',
#  'get_notifications',
#  'get_pending_invitations',
#  'get_projects',
#  'get_pull',
#  'get_pulls',
#  'get_pulls_comments',
#  'get_pulls_review_comments',
#  'get_readme',
#  'get_release',
#  'get_release_asset',
#  'get_releases',
#  'get_self_hosted_runner',
#  'get_self_hosted_runners',
#  'get_source_import',
#  'get_stargazers',
#  'get_stargazers_with_dates',
#  'get_stats_code_frequency',
#  'get_stats_commit_activity',
#  'get_stats_contributors',
#  'get_stats_participation',
#  'get_stats_punch_card',
#  'get_subscribers',
#  'get_tags',
#  'get_teams',
#  'get_top_paths',
#  'get_top_referrers',
#  'get_topics',
#  'get_views_traffic',
#  'get_vulnerability_alert',
#  'get_watchers',
#  'get_workflow',
#  'get_workflow_run',
#  'get_workflow_runs',
#  'get_workflows',
#  'git_commits_url',
#  'git_refs_url',
#  'git_tags_url',
#  'git_url',
#  'has_downloads',
#  'has_in_assignees',
#  'has_in_collaborators',
#  'has_issues',
#  'has_pages',
#  'has_projects',
#  'has_wiki',
#  'homepage',
#  'hooks_url',
#  'html_url',
#  'id',
#  'issue_comment_url',
#  'issue_events_url',
#  'issues_url',
#  'keys_url',
#  'labels_url',
#  'language',
#  'languages_url',
#  'last_modified',
#  'legacy_search_issues',
#  'mark_notifications_as_read',
#  'master_branch',
#  'merge',
#  'merges_url',
#  'milestones_url',
#  'mirror_url',
#  'name',
#  'network_count',
#  'notifications_url',
#  'open_issues',
#  'open_issues_count',
#  'organization',
#  'owner',
#  'parent',
#  'permissions',
#  'private',
#  'pulls_url',
#  'pushed_at',
#  'raw_data',
#  'raw_headers',
#  'releases_url',
#  'remove_from_collaborators',
#  'remove_invitation',
#  'remove_self_hosted_runner',
#  'replace_topics',
#  'setCheckAfterInitFlag',
#  'size',
#  'source',
#  'ssh_url',
#  'stargazers_count',
#  'stargazers_url',
#  'statuses_url',
#  'subscribe_to_hub',
#  'subscribers_count',
#  'subscribers_url',
#  'subscription_url',
#  'svn_url',
#  'tags_url',
#  'teams_url',
#  'trees_url',
#  'unsubscribe_from_hub',
#  'update',
#  'update_check_suites_preferences',
#  'update_file',
#  'updated_at',
#  'url',
#  'watchers',
#  'watchers_count']
