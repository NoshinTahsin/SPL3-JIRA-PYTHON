# %%
from jira import JIRA

jira = JIRA(basic_auth=('bsse0914@iit.du.ac.bd', 'MbaYDePZRnDgAdL062r83605'), options={'server':'https://pg-req.atlassian.net'})

# %%
#getting an issue
projects = jira.projects()
print(len(projects))
issues_in_proj = jira.search_issues('project=SAAJ')
print(issues_in_proj[2])
issue=jira.issue('SAAJ-4')
print(issue.fields.description)
print(issue.fields.summary)
print(issue.fields.assignee.accountId)
print(issue.fields.assignee.displayName)
# Out:
# 5
# SAAJ-4
# In the assignee suggestion table, add assignee image along with the assignee name to make the UI attractive
# Change the table in the UI
#
# 5e299526bf04010e70c42927
# Noshin Tahsin

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://pg-req.atlassian.net/rest/api/3/issue/SAAJ-4"

auth = HTTPBasicAuth("bsse0914@iit.du.ac.bd", "eVoC0zpgDFI1lS6B0jFZ7DB6")

headers = {
   "Accept": "application/json"
}

response = requests.request(
   "GET",
   url,
   headers=headers,
   auth=auth
)

print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))
# Out:
# {
#     "expand": "renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations",
#     "fields": {
#         "aggregateprogress": {
#             "progress": 0,
#             "total": 0
#         },
#         "aggregatetimeestimate": null,
#         "aggregatetimeoriginalestimate": null,
#         "aggregatetimespent": null,
#         "assignee": {
#             "accountId": "5e299526bf04010e70c42927",
#             "accountType": "atlassian",
#             "active": true,
#             "avatarUrls": {
#                 "16x16": "https://secure.gravatar.com/avatar/b130bf3b69479967b0fc12b90ff54231?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNT-4.png",
#                 "24x24": "https://secure.gravatar.com/avatar/b130bf3b69479967b0fc12b90ff54231?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNT-4.png",
# ...

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://pg-req.atlassian.net/rest/api/3/issue/SAAJ-5/assignee"

auth = HTTPBasicAuth("bsse0914@iit.du.ac.bd", "eVoC0zpgDFI1lS6B0jFZ7DB6")

headers = {
   "Accept": "application/json",
   "Content-Type": "application/json"
}

payload = json.dumps( {
  "accountId": "5e9412627bc0680c2ca4dd39"
} )

response = requests.request(
   "PUT",
   url,
   data=payload,
   headers=headers,
   auth=auth
)

print(response.text)
#print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://pg-req.atlassian.net/rest/api/2/user/assignable/search"

auth = HTTPBasicAuth("bsse0914@iit.du.ac.bd", "eVoC0zpgDFI1lS6B0jFZ7DB6")

headers = {
   "Accept": "application/json"
}

response = requests.request(
   "GET",
   url,
   headers=headers,
   auth=auth
)

print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))
# Out:
# {
#     "errorMessages": [
#         "No project or issue key was provided"
#     ],
#     "errors": {}
# }

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://pg-req.atlassian.net/rest/api/3/issue/SAAJ-4"

auth = HTTPBasicAuth("bsse0914@iit.du.ac.bd", "eVoC0zpgDFI1lS6B0jFZ7DB6")

headers = {
   "Accept": "application/json",
   "Content-Type": "application/json"
}

payload = json.dumps( {
  "fields": {
    "assignee":[
        {
            "accountId": "5e9412627bc0680c2ca4dd39",
        }
    ]
  }
} )

response = requests.request(
   "PUT",
   url,
   data=payload,
   headers=headers,
   auth=auth
)

print(response)

print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))
# Out:
# <Response [204]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-95d8458cc71a> in <module>
#      34 print(response)
#      35
# ---> 36 print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))
#
# G:\anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# G:\anaconda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://pg-req.atlassian.net/rest/api/3/issue/SAAJ-4"

auth = HTTPBasicAuth("bsse0914@iit.du.ac.bd", "eVoC0zpgDFI1lS6B0jFZ7DB6")

headers = {
   "Accept": "application/json"
}

response = requests.request(
   "GET",
   url,
   headers=headers,
   auth=auth
)

print(json.dumps(json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")))
# Out:
# {
#     "expand": "renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations",
#     "fields": {
#         "aggregateprogress": {
#             "progress": 0,
#             "total": 0
#         },
#         "aggregatetimeestimate": null,
#         "aggregatetimeoriginalestimate": null,
#         "aggregatetimespent": null,
#         "assignee": null,
#         "attachment": [],
#         "comment": {
#             "comments": [],
#             "maxResults": 0,
#             "startAt": 0,
#             "total": 0
#         },
#         "components": [],
#         "created": "2020-09-06T09:29:11.791-0700",
#         "creator": {
#             "accountId": "5e299526bf04010e70c42927",
#             "accountType": "atlassian",
#             "active": true,
#             "avatarUrls": {
# ...
